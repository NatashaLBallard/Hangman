# %% [markdown]
# <h1>Hangman</h1>
# </br>
#
# <p style="font-size: 16px">
# Develop a program that lets users guess the letters of the word until solved or out of guesses. The program will grab a word from the list and the user will ask the computer if the letter is in the word. Computer will visualize the Yes or No then return the updated hangman to user, with the remaining number of guesses.
# </p>
#
# <br/>

# %%
health = ['exercise', 'nutrition', 'cholesterol']
wealth = ['budget', 'dividends', 'retirement']
happiness = ['freedom', 'vacations', 'sunflowers']


gameWordLetters = []

def selectCategory (setCategory):
    category = []
    
    if setCategory == "he":
        category = health.copy()
        #print(category)          #For Testing Purposes
    elif setCategory == "we":
        category = wealth.copy()
        #print(category)          #For Testing Purposes
    elif setCategory == "ha":
        category = happiness.copy()
        #print(category)          #For Testing Purposes
    else :
        print("Invalid. Try again.")
    return category 


def selectLevel (setLevel):
    if level == 0 :
        print("Game Level: Easy" + "\n")
    elif level == 1 :
        print("Game Level: Medium" + "\n")
    elif level == 2 :
        print("Game Level: Hard" + "\n")
    else : 
        print("Invalid. Try again.")
    return level


def guessWord (guessLetter):
    counter = length
    while counter > 0:
        if guessLetter in wordAsList:
            print("Yes")
            counter =-1
        else:
            print("Yes")
            counter =-1

# %%
# Select Category
setCategory = input("Pick Category: ")

# Select Level
level = int(input("Select LeveL: ")) -1


# Select Word
gameCategory = selectCategory(setCategory)
gameLevel = selectLevel(setLevel)
gameWord = gameCategory[gameLevel]
#print(gameCategory, gameLevel)          #For Testing Purposes
#print(gameWord)                         #For Testing Purposes

# Get Length of Word
length = len(gameWord)
print("Length of Word: ",length)


# Slice and Store Word in List
wordAsList = list(gameWord)
print(wordAsList)


guessLetter = input("Guess letter: ")
#print(guessLetter in wordAsList)
counter = length
while counter >= 0:
    if guessLetter in wordAsList:
        print("Yes")
        counter -=1
    else:
        print("No")
        counter -=1
    guessLetter = input("Guess letter: ")
# Out:
# Pick Category: he
# Select LeveL: 1
# Game Level: Easy
#
# Length of Word:  8
# ['e', 'x', 'e', 'r', 'c', 'i', 's', 'e']
# Guess letter: e
# Yes
# Guess letter: x
# Yes
# Guess letter: r
# Yes
# Guess letter: c
# Yes
# Guess letter: i
# Yes
# Guess letter: s
# Yes
# Guess letter: f
# No
# Guess letter: j
# No
# Guess letter: k
# No
# Guess letter: k
